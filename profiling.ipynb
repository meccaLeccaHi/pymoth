# %%
## snakeviz with ipython/jupyter notbook
# %load_ext snakeviz

# %snakeviz run -i 'runMothLearnerMNIST.py'

# %%
## snakeviz without ipython/jupyter notbook

# $ python -m cProfile -o prof_info runMothLearnerMNIST.py
# $ snakeviz prof_info
